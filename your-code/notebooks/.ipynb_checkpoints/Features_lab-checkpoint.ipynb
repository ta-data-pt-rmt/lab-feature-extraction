# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
#Import your libraries
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Introduction
#
# In this lab, we will use two datasets. Both datasets contain variables that describe apps from the Google Play Store. We will use our knowledge in feature extraction to process these datasets and prepare them for the use of a ML algorithm.

# %% [markdown]
# # Challenge 1 - Loading and Extracting Features from the First Dataset

# %% [markdown]
# #### In this challenge, our goals are:
#
# * Exploring the dataset.
# * Identify the columns with missing values.
# * Either replacing the missing values in each column or drop the columns.
# * Conver each column to the appropriate type.

# %% [markdown]
# #### The first dataset contains different information describing the apps.
#
# Load the dataset into the variable `google_play` in the cell below. The dataset is in the file `googleplaystore.csv`

# %%
pd.set_option('display.max_rows', None)

# %%
# Your code here:
google_play = pd.read_csv('../../data/googleplaystore.csv')

# %% [markdown]
# #### Examine all variables and their types in the following cell

# %%
# Your code here:
google_play.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### Since this dataset only contains one numeric column, let's skip the `describe()` function and look at the first 5 rows using the `head()` function

# %%
# Your code here:
google_play.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# #### We can see that there are a few columns that could be coerced to numeric.
#
# Start with the reviews column. We can evaluate what value is causing this column to be of object type finding the non-numeric values in this column. To do this, we recall the `to_numeric()` function. With this function, we are able to coerce all non-numeric data to null. We can then use the `isnull()` function to subset our dataframe using the True/False column that this function generates.
#
# In the cell below, transform the Reviews column to numeric and assign this new column to the variable `Reviews_numeric`. Make sure to coerce the errors.

# %%
# Your code here:
def convert_reviews_to_numeric(review):
    return pd.to_numeric(review, errors='coerce')
    
google_play['Reviews_numeric'] = google_play['Reviews'].apply(convert_reviews_to_numeric)

# %% [markdown]
# Next, create a column containing True/False values using the `isnull()` function. Assign this column to the `Reviews_isnull` variable.

# %%
# Your code here:
google_play['Reviews_isnull'] = google_play['Reviews_numeric'].isnull()

# %% [markdown]
# Finally, subset the `google_play` with `Reviews_isnull`. This should give you all the rows that contain non-numeric characters.
#
# Your output should look like:
#
# ![Reviews_bool.png](../images/reviews-bool.png)

# %%
# Your code here:
google_play[google_play['Reviews_isnull']==True]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  Reviews_numeric  Reviews_isnull
# 10472       1.0.19  4.0 and up         NaN              NaN            True

# %% [markdown]
# #### We see that Google Play is using a shorthand for millions.
#
# Let's write a function to transform this data.
#
# Steps:
#
# 1. Create a function that returns the correct numeric values of *Reviews*.
# 1. Define a test string with `M` in the last character.
# 1. Test your function with the test string. Make sure your function works correctly. If not, modify your functions and test again.

# %%
# Your code here

def convert_string_to_numeric(s):
    """
    Convert a string value to numeric. If the last character of the string is `M`, obtain the 
    numeric part of the string, multiply it with 1,000,000, then return the result. Otherwise, 
    convert the string to numeric value and return the result.
    
    Args:
        s: The Reviews score in string format.

    Returns:
        The correct numeric value of the Reviews score.
    """
    if s[-1] == 'M':
        return pd.to_numeric(s[:-1]) * 1_000_000
    else:
        return pd.to_numeric(s, errors='coerce')

test_string = '4.0M'

convert_string_to_numeric(test_string) == 4000000
# Out:
# True

# %% [markdown]
# The last step is to apply the function to the `Reviews` column in the following cell:

# %%
# Your code here:
google_play['Reviews'] = google_play['Reviews'].apply(convert_string_to_numeric)

# %% [markdown]
# Check the non-numeric `Reviews` row again. It should have been fixed now and you should see:
#
# ![Reviews_bool_fixed.png](../images/reviews-bool-fixed.png)

# %%
# Your code here
google_play[google_play['Reviews_isnull']==True]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  Reviews_numeric  Reviews_isnull
# 10472       1.0.19  4.0 and up         NaN              NaN            True

# %% [markdown]
# Also check the variable types of `google_play`. The `Reviews` column should be a `float64` type now.

# %%
# Your code here:
google_play.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews            float64
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Reviews_numeric    float64
# Reviews_isnull        bool
# dtype: object

# %% [markdown]
# #### The next column we will look at is `Size`. We start by looking at all unique values in `Size`:
#
# *Hint: use `unique()` ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html))*.

# %%
# Your code here:
google_play['Size'].unique
# Out:
# <bound method Series.unique of 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
# 5                      5.6M
# 6                       19M
# 7                       29M
# 8                       33M
# 9                      3.1M
# 10                      28M
# 11                      12M
# 12                      20M
# 13                      21M
# 14                      37M
# 15                     2.7M
# 16                     5.5M
# 17                      17M
# 18                      39M
# 19                      31M
# 20                      14M
# 21                      12M
# 22                     4.2M
# 23                     7.0M
# 24                      23M
# 25                     6.0M
# 26                      25M
# 27                     6.1M
# 28                     4.6M
# 29                     4.2M
# 30                     9.2M
# 31                     5.2M
# 32                      11M
# 33                      11M
# 34                     4.2M
# 35                     9.2M
# 36                      24M
# 37       Varies with device
# 38                      11M
# 39                     9.4M
# 40                      15M
# 41                      10M
# 42       Varies with device
# 43                     1.2M
# 44                      12M
# 45                      24M
# 46                      26M
# 47                     8.0M
# 48                     7.9M
# 49                      25M
# 50                      56M
# 51                      57M
# 52       Varies with device
# 53                      35M
# 54                      33M
# 55                      33M
# 56                     5.6M
# 57                      54M
# 58                     201k
# 59                     3.6M
# 60                     5.7M
# 61                      17M
# 62                     8.6M
# 63                     2.4M
# 64                      27M
# 65                     2.7M
# 66                     2.5M
# 67       Varies with device
# 68       Varies with device
# 69                     7.0M
# 70                      35M
# 71                      16M
# 72                      16M
# 73       Varies with device
# 74                      17M
# 75                     3.4M
# 76                     8.9M
# 77                     3.9M
# 78                     2.9M
# 79                      38M
# 80                      32M
# 81                      37M
# 82                      15M
# 83                     5.4M
# 84                      18M
# 85       Varies with device
# 86                      38M
# 87                     1.1M
# 88       Varies with device
# 89       Varies with device
# 90                     7.9M
# 91                      35M
# 92       Varies with device
# 93                      17M
# 94                      19M
# 95                      14M
# 96                     2.2M
# 97                     4.5M
# 98                      17M
# 99                      14M
# 100                    9.8M
# 101                     21M
# 102      Varies with device
# 103                     52M
# 104                     14M
# 105                     25M
# 106                    9.0M
# 107      Varies with device
# 108                     12M
# 109      Varies with device
# 110                     35M
# 111                    6.7M
# 112                     30M
# 113                    5.7M
# 114                    2.9M
# 115                     17M
# 116                    2.9M
# 117      Varies with device
# 118      Varies with device
# 119                    2.6M
# 120                    4.2M
# 121                    7.1M
# 122                     57M
# 123                    3.7M
# 124                     22M
# 125                     24M
# 126                    7.4M
# 127                     21M
# 128                    3.4M
# 129                    2.9M
# 130                    3.1M
# 131                    6.4M
# 132                    3.2M
# 133                    8.2M
# 134                    9.9M
# 135                    2.9M
# 136                     23M
# 137                    4.6M
# 138                    3.1M
# 139      Varies with device
# 140                    4.9M
# 141                    9.5M
# 142      Varies with device
# 143      Varies with device
# 144      Varies with device
# 145      Varies with device
# 146      Varies with device
# 147                    4.2M
# 148                    5.4M
# 149      Varies with device
# 150                    2.8M
# 151                    5.0M
# 152      Varies with device
# 153                    5.9M
# 154                     13M
# 155                    7.1M
# 156                    6.7M
# 157      Varies with device
# 158                     17M
# 159                     19M
# 160                    6.7M
# 161                     21M
# 162      Varies with device
# 163                    2.7M
# 164                     37M
# 165                     15M
# 166                     23M
# 167                     19M
# 168                     23M
# 169                     73M
# 170                    4.9M
# 171                    6.8M
# 172      Varies with device
# 173      Varies with device
# 174                    2.9M
# 175                    3.5M
# 176                    4.0M
# 177                     21M
# 178                    2.3M
# 179      Varies with device
# 180                    7.2M
# 181                     10M
# 182                    6.1M
# 183                    2.1M
# 184                     42M
# 185                    7.3M
# 186                     30M
# 187      Varies with device
# 188      Varies with device
# 189      Varies with device
# 190                     29M
# 191      Varies with device
# 192      Varies with device
# 193      Varies with device
# 194                     35M
# 195                    9.1M
# 196                     25M
# 197                    3.9M
# 198                     18M
# 199                     12M
# 200                     21M
# 201      Varies with device
# 202      Varies with device
# 203      Varies with device
# 204      Varies with device
# 205                     55M
# 206                    3.2M
# 207      Varies with device
# 208      Varies with device
# 209                     23k
# 210                     16M
# 211      Varies with device
# 212                     14M
# 213                     37M
# 214      Varies with device
# 215      Varies with device
# 216                     11M
# 217                     25M
# 218                    7.3M
# 219                    6.5M
# 220                     25M
# 221                    3.1M
# 222      Varies with device
# 223                    1.5M
# 224                    7.5M
# 225                    8.6M
# 226      Varies with device
# 227                    1.2M
# 228      Varies with device
# 229      Varies with device
# 230      Varies with device
# 231                     39M
# 232                     14M
# 233                     19M
# 234                    6.8M
# 235                     39M
# 236      Varies with device
# 237                     14M
# 238                     20M
# 239      Varies with device
# 240      Varies with device
# 241                     26M
# 242                     51M
# 243                     41M
# 244                     20M
# 245      Varies with device
# 246                     12M
# 247                     48M
# 248                     10M
# 249                     22M
# 250                     11M
# 251                    8.5M
# 252                    8.6M
# 253      Varies with device
# 254                     28M
# 255                     28M
# 256                     37M
# 257                    9.0M
# 258                     46M
# 259      Varies with device
# 260                     14M
# 261      Varies with device
# 262                     26M
# 263                     23M
# 264      Varies with device
# 265      Varies with device
# 266                     14M
# 267                     20M
# 268      Varies with device
# 269      Varies with device
# 270                     26M
# 271                     51M
# 272                     41M
# 273                     20M
# 274      Varies with device
# 275                     12M
# 276                     48M
# 277                     10M
# 278                     22M
# 279                     11M
# 280                    8.5M
# 281                    8.6M
# 282      Varies with device
# 283                     28M
# 284      Varies with device
# 285      Varies with device
# 286      Varies with device
# 287                     39M
# 288                     14M
# 289                     19M
# 290                    6.8M
# 291                     39M
# 292      Varies with device
# 293                     35M
# 294      Varies with device
# 295                     29M
# 296                     41M
# 297      Varies with device
# 298                    4.9M
# 299                     27M
# 300                     32M
# 301                     12M
# 302                     15M
# 303                     11M
# 304                     28M
# 305                    2.2M
# 306                    3.4M
# 307                    8.3M
# 308                    4.3M
# 309                    4.7M
# 310                     10M
# 311                     15M
# 312                    7.1M
# 313                     21M
# 314                    6.1M
# 315      Varies with device
# 316                     15M
# 317                     11M
# 318                     29M
# 319                    3.3M
# 320      Varies with device
# 321                     22M
# 322                     40M
# 323                     10M
# 324                    9.1M
# 325                    4.7M
# 326                     38M
# 327      Varies with device
# 328                    6.7M
# 329                     37M
# 330      Varies with device
# 331                    7.8M
# 332                     19M
# 333                    5.7M
# 334                     35M
# 335      Varies with device
# 336      Varies with device
# 337                     17M
# 338      Varies with device
# 339      Varies with device
# 340      Varies with device
# 341      Varies with device
# 342      Varies with device
# 343                    8.8M
# 344      Varies with device
# 345                     16M
# 346                     11M
# 347                     11M
# 348      Varies with device
# 349                     15M
# 350                    6.6M
# 351      Varies with device
# 352                    6.6M
# 353      Varies with device
# 354      Varies with device
# 355                    5.1M
# 356      Varies with device
# 357                     18M
# 358                    4.0M
# 359      Varies with device
# 360      Varies with device
# 361      Varies with device
# 362                     37M
# 363      Varies with device
# 364                     22M
# 365      Varies with device
# 366                    3.3M
# 367                     32M
# 368                     37M
# 369      Varies with device
# 370      Varies with device
# 371      Varies with device
# 372      Varies with device
# 373      Varies with device
# 374                     17M
# 375      Varies with device
# 376      Varies with device
# 377                     35M
# 378                     40M
# 379                     61M
# 380                     66M
# 381      Varies with device
# 382      Varies with device
# 383                     11M
# 384                     79k
# 385      Varies with device
# 386      Varies with device
# 387                     25M
# 388                     14M
# 389      Varies with device
# 390      Varies with device
# 391      Varies with device
# 392      Varies with device
# 393      Varies with device
# 394      Varies with device
# 395                     24M
# 396      Varies with device
# 397                     17M
# 398                    8.3M
# 399      Varies with device
# 400                    8.2M
# 401      Varies with device
# 402      Varies with device
# 403      Varies with device
# 404      Varies with device
# 405                    8.4M
# 406      Varies with device
# 407      Varies with device
# 408                    4.0M
# 409                     32M
# 410      Varies with device
# 411      Varies with device
# 412      Varies with device
# 413                    6.1M
# 414      Varies with device
# 415      Varies with device
# 416                    2.8M
# 417      Varies with device
# 418      Varies with device
# 419                    3.3M
# 420                     40M
# 421                    2.2M
# 422      Varies with device
# 423                    4.3M
# 424                    4.7M
# 425                    2.3M
# 426                    2.3M
# 427      Varies with device
# 428                     11M
# 429                    2.7M
# 430                     14M
# 431      Varies with device
# 432                     13M
# 433                    3.7M
# 434                     10M
# 435                     13M
# 436                     10M
# 437                     13M
# 438                    8.8M
# 439                    5.5M
# 440                     20M
# 441                     29M
# 442      Varies with device
# 443      Varies with device
# 444                     11M
# 445      Varies with device
# 446                     17M
# 447                     17M
# 448      Varies with device
# 449      Varies with device
# 450                    118k
# 451      Varies with device
# 452                     16M
# 453                    5.1M
# 454      Varies with device
# 455                     44M
# 456                    7.3M
# 457                     30M
# 458                    695k
# 459      Varies with device
# 460                    1.6M
# 461                     19M
# 462      Varies with device
# 463      Varies with device
# 464      Varies with device
# 465                     11M
# 466      Varies with device
# 467      Varies with device
# 468      Varies with device
# 469      Varies with device
# 470                     23M
# 471                     26M
# 472      Varies with device
# 473      Varies with device
# 474      Varies with device
# 475      Varies with device
# 476      Varies with device
# 477                    6.2M
# 478                     20M
# 479                     18k
# 480                    1.2M
# 481                     17M
# 482      Varies with device
# 483                     15M
# 484      Varies with device
# 485                     56M
# 486                     12M
# 487                     11M
# 488                     29M
# 489      Varies with device
# 490                     40M
# 491      Varies with device
# 492                     53M
# 493                    3.1M
# 494                     24M
# 495                     23M
# 496                    5.0M
# 497                     44M
# 498                     27M
# 499                    6.1M
# 500      Varies with device
# 501                     21M
# 502                     11M
# 503                     21M
# 504                     24M
# 505                     31M
# 506                     27M
# 507                    6.2M
# 508      Varies with device
# 509                     12M
# 510                    8.0M
# 511                    5.9M
# 512                    7.9M
# 513                    5.0M
# 514                    1.4M
# 515                     13M
# 516                     40M
# 517                     13M
# 518                     19M
# 519                    5.0M
# 520                     19M
# 521                     27M
# 522                    3.0M
# 523                     13M
# 524                    7.2M
# 525                     25M
# 526      Varies with device
# 527                    5.7M
# 528                    5.5M
# 529      Varies with device
# 530                    6.5M
# 531                    5.8M
# 532      Varies with device
# 533                    3.8M
# 534                     41M
# 535                    7.9M
# 536                    2.8M
# 537                     20M
# 538                     15M
# 539                     28M
# 540                    9.6M
# 541                     13M
# 542                     15M
# 543                     40M
# 544                     56M
# 545                     12M
# 546                    9.4M
# 547                     29M
# 548                     11M
# 549                     19M
# 550                     23M
# 551      Varies with device
# 552                     27M
# 553      Varies with device
# 554                     19M
# 555                     45M
# 556                     21M
# 557                     40M
# 558                     25M
# 559                     15M
# 560                     24M
# 561      Varies with device
# 562                     11M
# 563                     38M
# 564                     31M
# 565                    6.1M
# 566                     27M
# 567                     32M
# 568                     13M
# 569                     63M
# 570                     44M
# 571      Varies with device
# 572                     16M
# 573                     28M
# 574      Varies with device
# 575                    5.9M
# 576                     13M
# 577                    9.0M
# 578                     20M
# 579                    7.9M
# 580                     28M
# 581                     49M
# 582                     27M
# 583                     18M
# 584                     14M
# 585                     27M
# 586                     41M
# 587                     38M
# 588                    5.5M
# 589                     27M
# 590                    7.2M
# 591                     21M
# 592                    8.8M
# 593                     38M
# 594      Varies with device
# 595                     11M
# 596                    6.5M
# 597                     26M
# 598                     19M
# 599                    6.1M
# 600                     77M
# 601                    9.5M
# 602                     14M
# 603                     38M
# 604                     16M
# 605                    3.4M
# 606                    4.7M
# 607                    5.0M
# 608                    4.9M
# 609                    4.9M
# 610                     16M
# 611                    3.9M
# 612                    4.4M
# 613                    4.8M
# 614                    4.5M
# 615                     70M
# 616                    4.9M
# 617                    3.7M
# 618                    4.9M
# 619                     16M
# 620                    4.6M
# 621                    3.6M
# 622                     21M
# 623                     13M
# 624                    8.7M
# 625                    9.2M
# 626                    6.9M
# 627                     39M
# 628                    8.0M
# 629                    3.9M
# 630                     14M
# 631                     11M
# 632                     13M
# 633                    9.3M
# 634                    5.0M
# 635                   10.0M
# 636                    5.0M
# 637                    5.0M
# 638                    3.6M
# 639                     19M
# 640                    5.0M
# 641                    9.8M
# 642                     14M
# 643                    5.0M
# 644                    4.9M
# 645                    5.5M
# 646                     11M
# 647                    3.8M
# 648                    5.0M
# 649                    8.2M
# 650                     21M
# 651                     12M
# 652                     10M
# 653                    3.3M
# 654                     25M
# 655                     15M
# 656                     10M
# 657                    4.9M
# 658                    4.4M
# 659                    3.5M
# 660                    7.8M
# 661                    9.0M
# 662                     15M
# 663                     19M
# 664                     56M
# 665                     38M
# 666                     16M
# 667                    5.0M
# 668                     27M
# 669                    4.7M
# 670      Varies with device
# 671                    3.4M
# 672                    4.9M
# 673                     25M
# 674                     29M
# 675                    8.1M
# 676                     14M
# 677                     27M
# 678                    3.9M
# 679                     13M
# 680                    5.0M
# 681                    5.5M
# 682                     16M
# 683                    4.8M
# 684                     14M
# 685                    4.7M
# 686                    3.7M
# 687                    4.9M
# 688                    3.5M
# 689                    4.5M
# 690      Varies with device
# 691                     36M
# 692                    4.5M
# 693                     19M
# 694                     14M
# 695                     77M
# 696                     21M
# 697                    7.9M
# 698                    9.3M
# 699      Varies with device
# 700                     18M
# 701                     18M
# 702                     21M
# 703                    3.3M
# 704                     24M
# 705                     39M
# 706                    3.2M
# 707                    5.1M
# 708                     11M
# 709                     27M
# 710                     37M
# 711      Varies with device
# 712                     26M
# 713                     11M
# 714      Varies with device
# 715                     41M
# 716                     49M
# 717                     21M
# 718                    8.1M
# 719                     51M
# 720                     14M
# 721                     18M
# 722                    3.0M
# 723                     19M
# 724      Varies with device
# 725                     22M
# 726                    6.9M
# 727                    7.4M
# 728                     84M
# 729                     25M
# 730                     18M
# 731      Varies with device
# 732                    2.5M
# 733                    3.9M
# 734      Varies with device
# 735                     21M
# 736                     27M
# 737      Varies with device
# 738                     21M
# 739                     18M
# 740      Varies with device
# 741                     18M
# 742      Varies with device
# 743                     10M
# 744      Varies with device
# 745      Varies with device
# 746      Varies with device
# 747      Varies with device
# 748                     97M
# 749                     17M
# 750      Varies with device
# 751      Varies with device
# 752                    2.0M
# 753                    1.9M
# 754                    1.8M
# 755                    1.8M
# 756                     17M
# 757                     18M
# 758                    5.3M
# 759      Varies with device
# 760                    5.4M
# 761                    5.4M
# 762                    5.4M
# 763                     15M
# 764                    5.3M
# 765                     48M
# 766                    5.4M
# 767                     47M
# 768                    556k
# 769                     29M
# 770                    2.3M
# 771      Varies with device
# 772                    4.4M
# 773                    6.6M
# 774      Varies with device
# 775                    526k
# 776                     12M
# 777      Varies with device
# 778                     29M
# 779      Varies with device
# 780      Varies with device
# 781      Varies with device
# 782                     21M
# 783                     18M
# 784      Varies with device
# 785      Varies with device
# 786      Varies with device
# 787                     18M
# 788                     17M
# 789                     10M
# 790                     76M
# 791      Varies with device
# 792                     17M
# 793      Varies with device
# 794      Varies with device
# 795                     18M
# 796                     21M
# 797      Varies with device
# 798                    6.9M
# 799      Varies with device
# 800                     14M
# 801                     76M
# 802                     11M
# 803                     19M
# 804                    6.5M
# 805                    7.0M
# 806      Varies with device
# 807                    3.3M
# 808                     21M
# 809      Varies with device
# 810                    2.6M
# 811                     21M
# 812                    5.2M
# 813                     18M
# 814      Varies with device
# 815                     16M
# 816                     15M
# 817                    1.2M
# 818      Varies with device
# 819      Varies with device
# 820                     18M
# 821                    1.8M
# 822                    7.6M
# 823      Varies with device
# 824      Varies with device
# 825                     59M
# 826      Varies with device
# 827                    6.9M
# 828                     14M
# 829                     41M
# 830                     19M
# 831                     76M
# 832      Varies with device
# 833                     21M
# 834                     21M
# 835                     21M
# 836      Varies with device
# 837                     21M
# 838      Varies with device
# 839      Varies with device
# 840                    5.4M
# 841                    7.3M
# 842      Varies with device
# 843                     59M
# 844                     41M
# 845      Varies with device
# 846                     21M
# 847                     76M
# 848                    7.6M
# 849      Varies with device
# 850                     13M
# 851                     63M
# 852                     44M
# 853                     24M
# 854                     24M
# 855      Varies with device
# 856                    4.5M
# 857      Varies with device
# 858                     11M
# 859      Varies with device
# 860                    4.6M
# 861      Varies with device
# 862      Varies with device
# 863                    3.3M
# 864                    6.5M
# 865      Varies with device
# 866      Varies with device
# 867      Varies with device
# 868                     12M
# 869      Varies with device
# 870                    5.6M
# 871                    9.7M
# 872                     15M
# 873      Varies with device
# 874                     52M
# 875      Varies with device
# 876      Varies with device
# 877                    4.5M
# 878      Varies with device
# 879                     49M
# 880                     18M
# 881                     13M
# 882                    4.0M
# 883                     16M
# 884                     17M
# 885      Varies with device
# 886                     24M
# 887      Varies with device
# 888                     12M
# 889      Varies with device
# 890                     78M
# 891      Varies with device
# 892                     25M
# 893                     57M
# 894      Varies with device
# 895                    9.1M
# 896                     39M
# 897      Varies with device
# 898                     16M
# 899      Varies with device
# 900                    8.5M
# 901                     12M
# 902                     72M
# 903                     12M
# 904      Varies with device
# 905      Varies with device
# 906                     16M
# 907                    9.6M
# 908      Varies with device
# 909                     22M
# 910      Varies with device
# 911                     13M
# 912      Varies with device
# 913                     12M
# 914      Varies with device
# 915                     23M
# 916                     20M
# 917                     25M
# 918                     17M
# 919      Varies with device
# 920                     19M
# 921                     21M
# 922                     19M
# 923      Varies with device
# 924      Varies with device
# 925      Varies with device
# 926      Varies with device
# 927                     19M
# 928                    4.4M
# 929                     19M
# 930                     12M
# 931      Varies with device
# 932                     11M
# 933      Varies with device
# 934      Varies with device
# 935      Varies with device
# 936                     12M
# 937                     25M
# 938      Varies with device
# 939      Varies with device
# 940                     21M
# 941                     13M
# 942                     17M
# 943                     20M
# 944      Varies with device
# 945                     20M
# 946                     19M
# 947                     17M
# 948                     21M
# 949                     15M
# 950                     19M
# 951                     19M
# 952                    7.2M
# 953                     32M
# 954      Varies with device
# 955      Varies with device
# 956                     44M
# 957                     19M
# 958      Varies with device
# 959                     11M
# 960      Varies with device
# 961      Varies with device
# 962      Varies with device
# 963                     25M
# 964      Varies with device
# 965      Varies with device
# 966      Varies with device
# 967      Varies with device
# 968                     16M
# 969      Varies with device
# 970                     20M
# 971      Varies with device
# 972                     21M
# 973                     30M
# 974      Varies with device
# 975      Varies with device
# 976                     57M
# 977                     19M
# 978                     17M
# 979      Varies with device
# 980                     15M
# 981                     19M
# 982                     19M
# 983                     19M
# 984                     44M
# 985                     19M
# 986                     35M
# 987                     44M
# 988      Varies with device
# 989      Varies with device
# 990                     20M
# 991                     19M
# 992                     25M
# 993      Varies with device
# 994                     43M
# 995      Varies with device
# 996      Varies with device
# 997                    3.6M
# 998                    7.7M
# 999                     44M
# 1000                    12M
# 1001                    53M
# 1002                    77M
# 1003     Varies with device
# 1004                   9.5M
# 1005                    36M
# 1006                   6.3M
# 1007                   5.9M
# 1008     Varies with device
# 1009                    12M
# 1010                   2.8M
# 1011                    26M
# 1012                   8.7M
# 1013                    16M
# 1014                    53M
# 1015     Varies with device
# 1016                    14M
# 1017                   8.9M
# 1018                    11M
# 1019                   334k
# 1020                    24M
# 1021                    13M
# 1022     Varies with device
# 1023                   2.8M
# 1024                   9.7M
# 1025                   1.4M
# 1026     Varies with device
# 1027                   3.5M
# 1028                    61M
# 1029                   6.0M
# 1030                   2.3M
# 1031                   9.0M
# 1032                    11M
# 1033                    27M
# 1034                   3.6M
# 1035     Varies with device
# 1036                    29M
# 1037                   4.4M
# 1038                    21M
# 1039                    13M
# 1040                    27M
# 1041                    11M
# 1042                    24M
# 1043                   6.1M
# 1044                   6.3M
# 1045                    23M
# 1046                    34M
# 1047                   3.8M
# 1048     Varies with device
# 1049     Varies with device
# 1050                    42M
# 1051     Varies with device
# 1052                    19M
# 1053                    70M
# 1054                    32M
# 1055                    93M
# 1056     Varies with device
# 1057     Varies with device
# 1058     Varies with device
# 1059                    40M
# 1060                    24M
# 1061     Varies with device
# 1062                    20M
# 1063                    15M
# 1064                    28M
# 1065                    10M
# 1066     Varies with device
# 1067     Varies with device
# 1068     Varies with device
# 1069                    14M
# 1070     Varies with device
# 1071                    42M
# 1072                    65M
# 1073                    37M
# 1074     Varies with device
# 1075                    39M
# 1076                    47M
# 1077                    79M
# 1078                    18M
# 1079     Varies with device
# 1080                   100M
# 1081                    32M
# 1082                    46M
# 1083     Varies with device
# 1084                   9.8M
# 1085                   8.2M
# 1086                    18M
# 1087     Varies with device
# 1088                    39M
# 1089                    44M
# 1090     Varies with device
# 1091                   5.0M
# 1092                    21M
# 1093                    22M
# 1094                    23M
# 1095     Varies with device
# 1096     Varies with device
# 1097     Varies with device
# 1098                    27M
# 1099     Varies with device
# 1100                   5.0M
# 1101                    32M
# 1102                   7.4M
# 1103                    24M
# 1104                    22M
# 1105     Varies with device
# 1106                    10M
# 1107                    17M
# 1108                    38M
# 1109                    46M
# 1110                   3.8M
# 1111                   9.3M
# 1112                   8.4M
# 1113                    28M
# 1114     Varies with device
# 1115                   9.7M
# 1116                    11M
# 1117     Varies with device
# 1118                   7.4M
# 1119                    19M
# 1120                    16M
# 1276                   8.8M
# 1277     Varies with device
# 1278                   4.0M
# 1279                   6.9M
# 1280                    11M
# 1281     Varies with device
# 1282                   5.5M
# 1283     Varies with device
# 1284                    15M
# 1285                   4.3M
# 1286     Varies with device
# 1287                   7.1M
# 1288                    58M
# 1289     Varies with device
# 1290     Varies with device
# 1291                    18M
# 1292     Varies with device
# 1293                   1.5M
# 1294                   6.5M
# 1295                    11M
# 1296                    67M
# 1297     Varies with device
# 1298                    57M
# 1299                    59M
# 1300                    48M
# 1301                    57M
# 1302                    13M
# 1303     Varies with device
# 1304     Varies with device
# 1305     Varies with device
# 1306                    31M
# 1307                    10M
# 1308                    57M
# 1309     Varies with device
# 1310                    21M
# 1311                    25M
# 1312                    93M
# 1313                    60M
# 1314                    27M
# 1315                    54M
# 1316     Varies with device
# 1317     Varies with device
# 1318                    59M
# 1319     Varies with device
# 1320                    78M
# 1321                    55M
# 1322     Varies with device
# 1323     Varies with device
# 1324                    67M
# 1325     Varies with device
# 1326                    35M
# 1327     Varies with device
# 1328                    43M
# 1329                    39M
# 1330                   4.2M
# 1331                    44M
# 1332                    45M
# 1333     Varies with device
# 1334                    28M
# 1335                    29M
# 1336                    12M
# 1337                    15M
# 1338                    31M
# 1339     Varies with device
# 1340     Varies with device
# 1341     Varies with device
# 1342     Varies with device
# 1343                    20M
# 1344                    39M
# 1345                    94M
# 1346                    35M
# 1347     Varies with device
# 1348     Varies with device
# 1349                    41M
# 1350                    49M
# 1351                    22M
# 1352     Varies with device
# 1353                    23M
# 1354                    28M
# 1355                   7.2M
# 1356                   6.5M
# 1357     Varies with device
# 1358                    24M
# 1359     Varies with device
# 1360     Varies with device
# 1361                    20M
# 1362     Varies with device
# 1363                    15M
# 1364     Varies with device
# 1365                    55M
# 1366     Varies with device
# 1367                    38M
# 1368                    32M
# 1369     Varies with device
# 1370     Varies with device
# 1371                    40M
# 1372                    59M
# 1373     Varies with device
# 1374     Varies with device
# 1375     Varies with device
# 1376                    23M
# 1377                   6.1M
# 1378     Varies with device
# 1379                    58M
# 1380                    55M
# 1381     Varies with device
# 1382     Varies with device
# 1383                    57M
# 1384                    93M
# 1385                    60M
# 1386     Varies with device
# 1387     Varies with device
# 1388     Varies with device
# 1389     Varies with device
# 1390     Varies with device
# 1391     Varies with device
# 1392                    19M
# 1393                   3.8M
# 1394                    18M
# 1395                    57M
# 1396                   5.5M
# 1397     Varies with device
# 1398                   5.7M
# 1399                    51M
# 1400                   9.4M
# 1401                   3.3M
# 1402     Varies with device
# 1403                   4.0M
# 1404     Varies with device
# 1405     Varies with device
# 1406                    19M
# 1407                   3.8M
# 1408                   4.3M
# 1409                    18M
# 1410                   5.7M
# 1411     Varies with device
# 1412                   3.6M
# 1413                   5.5M
# 1414                    57M
# 1415                    51M
# 1416                    58M
# 1417     Varies with device
# 1418                   9.4M
# 1419                   3.3M
# 1420                   4.0M
# 1421     Varies with device
# 1422     Varies with device
# 1423                   9.9M
# 1424                    43M
# 1425                    37M
# 10756                  2.5M
# 10757                   72M
# 10758                  4.3M
# 10759                   67k
# 10760                  2.4M
# 10761                  8.0M
# 10762                   11M
# 10763                  552k
# 10764                  885k
# 10765    Varies with device
# 10766                  7.0M
# 10767                   16M
# 10768                   24M
# 10769                   12M
# 10770                   41M
# 10771                  2.4M
# 10772                  3.9M
# 10773                  8.9M
# 10774                   36M
# 10775                  9.0M
# 10776                   24M
# 10777                  2.2M
# 10778                   38M
# 10779                   75M
# 10780                   50M
# 10781                   44M
# 10782                   11M
# 10783                   72M
# 10784                   84M
# 10785                  9.5M
# 10786                  2.8M
# 10787                   48M
# 10788                   20M
# 10789                   48M
# 10790                   20M
# 10791                   38M
# 10792                   16M
# 10793                   78M
# 10794                  5.7M
# 10795                  4.0M
# 10796                  7.8M
# 10797                   46M
# 10798                 1020k
# 10799                  6.8M
# 10800                   12M
# 10801                   19M
# 10802                   28M
# 10803                   81M
# 10804                   17M
# 10805                   15M
# 10806                   42M
# 10807                  4.2M
# 10808                  1.0M
# 10809                   24M
# 10810                   21M
# 10811                  3.9M
# 10812                   13M
# 10813                  2.7M
# 10814                   31M
# 10815                  4.9M
# 10816                  6.8M
# 10817                  8.0M
# 10818                  1.5M
# 10819                  3.6M
# 10820                  8.6M
# 10821                  2.5M
# 10822                  3.1M
# 10823                  2.9M
# 10824                   82M
# 10825                  7.7M
# 10826    Varies with device
# 10827                   13M
# 10828                   13M
# 10829                  7.4M
# 10830                  2.3M
# 10831                  9.8M
# 10832                  582k
# 10833                  619k
# 10834                  2.6M
# 10835                  9.6M
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, dtype: object>

# %% [markdown]
# You should have seen lots of unique values of the app sizes.
#
# #### While we can convert most of the `Size` values to numeric in the same way we converted the `Reviews` values, there is one value that is impossible to convert.
#
# What is that badass value? Enter it in the next cell and calculate the proportion of its occurence to the total number of records of `google_play`.

# %%
# Your code here:
'''
The value is names "varies with device" and it shows up 1695 times, which amounts to about 15% of times.
'''

google_play['Size'].value_counts()/(len(google_play['Size']))
# Out:
# Varies with device    0.156351
# 11M                   0.018264
# 12M                   0.018080
# 14M                   0.017895
# 13M                   0.017618
# 15M                   0.016973
# 17M                   0.014759
# 19M                   0.014205
# 26M                   0.013744
# 16M                   0.013744
# 25M                   0.013191
# 20M                   0.012822
# 21M                   0.012729
# 10M                   0.012545
# 24M                   0.012545
# 18M                   0.012268
# 23M                   0.010792
# 22M                   0.010516
# 29M                   0.009501
# 27M                   0.008948
# 28M                   0.008763
# 30M                   0.007748
# 33M                   0.007287
# 3.3M                  0.007103
# 37M                   0.007010
# 35M                   0.006641
# 31M                   0.006457
# 2.9M                  0.006365
# 2.5M                  0.006272
# 2.3M                  0.006272
# 2.8M                  0.005996
# 3.4M                  0.005996
# 32M                   0.005811
# 34M                   0.005811
# 3.7M                  0.005811
# 40M                   0.005719
# 3.9M                  0.005719
# 3.8M                  0.005719
# 4.0M                  0.005627
# 44M                   0.005627
# 3.0M                  0.005627
# 36M                   0.005535
# 48M                   0.005442
# 46M                   0.005442
# 904k                  0.000092
# 175k                  0.000092
# 350k                  0.000092
# 454k                  0.000092
# 496k                  0.000092
# 421k                  0.000092
# 812k                  0.000092
# 442k                  0.000092
# 412k                  0.000092
# 459k                  0.000092
# 478k                  0.000092
# 782k                  0.000092
# 721k                  0.000092
# 430k                  0.000092
# 429k                  0.000092
# 200k                  0.000092
# 460k                  0.000092
# 728k                  0.000092
# 619k                  0.000092
# Name: Size, dtype: float64

# %% [markdown]
# #### While this column may be useful for other types of analysis, we opt to drop it from our dataset.
#
# There are two reasons. First, the majority of the data are ordinal but a sizeable proportion are missing because we cannot convert them to numerical values. Ordinal data are both numerical and categorical, and they usually can be ranked (e.g. 82k is smaller than 91M). In contrast, non-ordinal categorical data such as blood type and eye color cannot be ranked. The second reason is as a categorical column, it has too many unique values to produce meaningful insights. Therefore, in our case the simplest strategy would be to drop the column.
#
# Drop the column in the cell below (use `inplace=True`)

# %%
# Your code here:
google_play.drop(['Size'], axis=1, inplace=True)

# %% [markdown]
# #### Now let's look at how many missing values are in each column.
#
# This will give us an idea of whether we should come up with a missing data strategy or give up on the column all together. In the next column, find the number of missing values in each column:
#
# *Hint: use the `isna()` and `sum()` functions.*

# %%
# Your code here:
google_play.isna().sum()
# Out:
# App                   0
# Category              0
# Rating             1474
# Reviews               0
# Installs              0
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# Reviews_numeric       1
# Reviews_isnull        0
# dtype: int64

# %% [markdown]
# You should find the column with the most missing values is now `Rating`.
#
# #### What is the proportion of the missing values in `Rating` to the total number of records?
#
# Enter your answer in the cell below.

# %%
# Your code here:
'''
The proportion is about 13.5%
'''

google_play.isna().sum()/len(google_play)
# Out:
# App                0.000000
# Category           0.000000
# Rating             0.135965
# Reviews            0.000000
# Installs           0.000000
# Type               0.000092
# Price              0.000000
# Content Rating     0.000092
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.000738
# Android Ver        0.000277
# Reviews_numeric    0.000092
# Reviews_isnull     0.000000
# dtype: float64

# %% [markdown]
# A sizeable proportion of the `Rating` column is missing. A few other columns also contain several missing values.
#
# #### We opt to preserve these columns and remove the rows containing missing data.
#
# In particular, we don't want to drop the `Rating` column because:
#
# * It is one of the most important columns in our dataset.
#
# * Since the dataset is not a time series, the loss of these rows will not have a negative impact on our ability to analyze the data. It will, however, cause us to lose some meaningful observations. But the loss is limited compared to the gain we receive by preserving these columns.
#
# In the cell below, remove all rows containing at least one missing value. Use the `dropna()` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html)). Assign the new dataframe to the variable `google_missing_removed`.

# %%
# Your code here:
google_missing_removed=google_play.dropna()

# %% [markdown]
# From now on, we use the `google_missing_removed` variable instead of `google_play`.
#
# #### Next, we look at the `Last Updated` column.
#
# The `Last Updated` column seems to contain a date, though it is classified as an object type. Let's convert this column using the `pd.to_datetime` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)).

# %%
# Your code here:
google_missing_removed['Last Updated'] = pd.to_datetime(google_missing_removed['Last Updated'])
# Out:
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_8256\2467473143.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_missing_removed['Last Updated'] = pd.to_datetime(google_missing_removed['Last Updated'])

# %%
google_missing_removed.dtypes
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                   float64
# Installs                   object
# Type                       object
# Price                      object
# Content Rating             object
# Genres                     object
# Last Updated       datetime64[ns]
# Current Ver                object
# Android Ver                object
# Reviews_numeric           float64
# Reviews_isnull               bool
# dtype: object

# %% [markdown]
# #### The last column we will transform is `Price`.
#
# We start by looking at the unique values of this column.

# %%
# Your code here:
google_missing_removed['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %% [markdown]
# Since all prices are ordinal data without exceptions, we can tranform this column by removing the dollar sign and converting to numeric. We can create a new column called `Price Numerical` and drop the original column.
#
# We will achieve our goal in three steps. Follow the instructions of each step below.
#
# #### First we remove the dollar sign. Do this in the next cell by applying the `str.replace` function to the column to replace `$` with an empty string (`''`).

# %%
# Your code here:
google_missing_removed['Price Numerical'] = google_missing_removed['Price'].str.replace('$','')
# Out:
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_8256\1696754349.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   google_missing_removed['Price Numerical'] = google_missing_removed['Price'].str.replace('$','')
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_8256\1696754349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_missing_removed['Price Numerical'] = google_missing_removed['Price'].str.replace('$','')

# %% [markdown]
# #### Second step, coerce the `Price Numerical` column to numeric.

# %%
# Your code here:
def convert_price_to_numeric(price):
    return pd.to_numeric(price, errors='coerce')
    
google_missing_removed['Price Numerical'] = google_missing_removed['Price Numerical'].apply(convert_price_to_numeric)
# Out:
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_8256\2489855875.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_missing_removed['Price Numerical'] = google_missing_removed['Price Numerical'].apply(convert_price_to_numeric)

# %% [markdown]
# **Finally, drop the original `Price` column.**

# %%
# Your code here:
google_missing_removed.drop(['Price'], axis=1, inplace=True)
# Out:
# C:\Users\gelorminim\AppData\Local\Temp\ipykernel_8256\2049808471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_missing_removed.drop(['Price'], axis=1, inplace=True)

# %% [markdown]
# Now check the variable types of `google_missing_removed`. Make sure:
#
# * `Size` and `Price` columns have been removed.
# * `Rating`, `Reviews`, and `Price Numerical` have the type of `float64`.
# * `Last Updated` has the type of `datetime64`.

# %%
# Your code here
google_missing_removed.dtypes
# Out:
# App                        object
# Category                   object
# Rating                    float64
# Reviews                   float64
# Installs                   object
# Type                       object
# Content Rating             object
# Genres                     object
# Last Updated       datetime64[ns]
# Current Ver                object
# Android Ver                object
# Reviews_numeric           float64
# Reviews_isnull               bool
# Price Numerical           float64
# dtype: object

# %% [markdown]
# # Challenge 2 - Loading and Extracting Features from the Second Dataset

# %% [markdown]
# Load the second dataset to the variable `google_reviews`. The data is in the file `googleplaystore_user_reviews.csv`.

# %%
# Your code here:
google_reviews = pd.read_csv('../../data/googleplaystore_user_reviews.csv')

# %% [markdown]
# #### This dataset contains the top 100 reviews for each app.
#
# Let's examine this dataset using the `head` function

# %%
# Your code here
google_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# #### The main piece of information we would like to extract from this dataset is the proportion of positive reviews of each app.
#
# Columns like `Sentiment_Polarity` and `Sentiment_Subjectivity` are not to our interests because we have no clue how to use them. We do not care about `Translated_Review` because natural language processing is too complex for us at present (in fact the `Sentiment`, `Sentiment_Polarity`, and `Sentiment_Subjectivity` columns are derived from `Translated_Review` the data scientists).
#
# What we care about in this challenge is `Sentiment`. To be more precise, we care about **what is the proportion of *Positive* sentiment of each app**. This will require us to aggregate the `Sentiment` data by `App` in order to calculate the proportions.
#
# Now that you are clear about what we are trying to achieve, follow the steps below that will walk you through towards our goal.

# %% [markdown]
# #### Our first step will be to remove all rows with missing sentiment.
#
# In the next cell, drop all rows with missing data using the `dropna()` function and assign this new dataframe to `review_missing_removed`.

# %%
# Your code here:
review_missing_removed = google_reviews.copy()
review_missing_removed = review_missing_removed.dropna()

# %% [markdown]
# #### Now, use the `value_counts()` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html)) to get a sense on how many apps are in this dataset and their review counts.

# %%
# Your code here:
review_missing_removed['App'].value_counts()
# Out:
# Bowmasters                                            312
# Helix Jump                                            273
# Angry Birds Classic                                   273
# Calorie Counter - MyFitnessPal                        254
# Duolingo: Learn Languages Free                        240
# Candy Crush Saga                                      240
# Garena Free Fire                                      222
# 8 Ball Pool                                           219
# Calorie Counter - Macros                              200
# 10 Best Foods for You                                 194
# CBS Sports App - Scores, News, Stats & Watch Live     192
# Google Photos                                         191
# Alto's Adventure                                      175
# 8fit Workouts & Meal Planner                          171
# DRAGON BALL LEGENDS                                   167
# Candy Crush Soda Saga                                 166
# Clash Royale                                          165
# Adobe Acrobat Reader                                  162
# Episode - Choose Your Story                           160
# Flow Free                                             154
# Block Puzzle                                          154
# Bubble Shooter                                        145
# Calorie Counter - MyNetDiary                          139
# Agar.io                                               136
# Cooking Fever                                         135
# Calorie Counter & Diet Tracker                        135
# Galaxy Attack: Alien Shooter                          134
# Colorfy: Coloring Book for Adults - Free              133
# Gardenscapes                                          133
# Facebook                                              132
# ColorNote Notepad Notes                               131
# Expedia Hotels, Flights & Car Rental Travel Deals     128
# HotelTonight: Book amazing deals at great hotels      127
# DEAD TARGET: FPS Zombie Apocalypse Survival Games     125
# Fishdom                                               123
# Groupon - Shop Deals, Discounts & Coupons             120
# Badoo - Free Chat & Dating App                        120
# Gyft - Mobile Gift Card Wallet                        120
# Booking.com Travel Deals                              120
# Crunchyroll - Everything Anime                        120
# Google Keep                                           120
# Amazon Kindle                                         117
# Google Pay                                            117
# Fly Delta                                              71
# FlirtChat - ♥Free Dating/Flirting App♥                 70
# ABC News - US & World News                             70
# Hinge: Dating & Relationships                          69
# Avakin Life - 3D virtual world                         69
# Fantasy Football                                       69
# Apartments.com Rental Search                           69
# Hotels.com: Book Hotel Rooms & Find Vacation Deals     68
# Fake Call - Fake Caller ID                             67
# Free Dating App - Meet Local Singles - Flirt Chat      67
# Hello Stars                                            67
# HipChat - Chat Built for Teams                         66
# Fandango Movies - Times + Tickets                      66
# DreamWorks Friends                                     66
# ASOS                                                   66
# Calm - Meditate, Sleep, Relax                          65
# Hostelworld: Hostels & Cheap Hotels Travel App         65
# Hello Kitty Nail Salon                                 65
# All Mental disorders                                   65
# Anthem Anywhere                                        65
# Gmail                                                  64
# Flickr                                                 64
# Hill Climb Racing 2                                    64
# Firefox Focus: The privacy browser                     64
# Free Dating Hook Up Messenger                          64
# Filters for Selfie                                     63
# Ada - Your Health Guide                                63
# BBC News                                               63
# DisneyNOW – TV Shows & Games                           63
# Firefox Browser fast & private                         62
# Airbnb                                                 62
# Cat Sim Online: Play with Cats                         61
# HISTORY: Watch TV Show Full Episodes & Specials        61
# Four In A Line                                         61
# Hay Day                                                61
# Apex Launcher                                          60
# Frozen Free Fall                                       60
# Free Dating App - YoCutie - Flirt, Chat & Meet         59
# DU Recorder – Screen Recorder, Video Editor, Live      58
# Home Street – Home Design Game                         57
# CATS: Crash Arena Turbo Stars                          57
# Digit Save Money Automatically                         56
# Aprender inglés con Wlingua                            56
# CBS Sports Fantasy                                     54
# Harry Potter: Hogwarts Mystery                         54
# Hide App, Private Dating, Safe Chat - PrivacyHider     53
# Domino's Pizza USA                                     53
# HD Camera for Android                                  52
# Diary with lock password                               52
# Homescapes                                             52
# Baby Panda Care                                        50
# AdWords Express                                        50
# BBC Sport                                              49
# Fortune City - A Finance App                           48
# Babbel – Learn Languages                               48
# Apartment List: Housing, Apt, and Property Rentals     47
# Disney Magic Kingdoms: Build Your Own Magical Park     47
# Easy - taxi, car, ridesharing                          46
# Amazon Shopping                                        45
# AliExpress - Smarter Shopping, Better Living           45
# Apartments & Rentals - Zillow                          44
# Coloring book moana                                    44
# Hill Climb Racing                                      44
# American Airlines                                      43
# Asana: organize team projects                          43
# Android Messages                                       43
# Adobe Photoshop Express:Photo Editor Collage Maker     42
# Facetune - Ad Free                                     42
# A+ Gallery - Photos & Videos                           41
# Food Calorie Calculator                                41
# Guns of Glory                                          40
# Blood Pressure Log - MyDiary                           40
# Blood Pressure(BP) Diary                               40
# Current debit card and app made for teens              40
# Bloomberg Professional                                 40
# Bloomberg: Market & Financial News                     40
# Cricket Visual Voicemail                               40
# Citi Mobile®                                           40
# H Pack                                                 40
# Boxed Wholesale                                        40
# Candy Pop Story                                        40
# Candy Smash                                            40
# Hacker's Keyboard                                      40
# Chakra Cleansing                                       40
# Championat                                             40
# Chase Mobile                                           40
# HTC Service—Video Player                               40
# CheckPoints 🏆 Rewards App                              40
# HTC Sense Input-AR                                     40
# Cinemark Theatres                                      40
# Cisco Webex Teams                                      40
# DU Browser—Browse fast & fun                           40
# CityMaps2Go Plan Trips Travel Guide Offline Maps       40
# Claro                                                  40
# HTC Sense Input                                        40
# 2GIS: directory & navigator                            40
# HTC Mail                                               40
# HTC Help                                               40
# Content Transfer                                       40
# ConvertPad - Unit Converter                            40
# 2ndLine - Second Phone Number                          40
# Couch to 10K Running Trainer                           40
# Brasileirão Pro 2018 - Série A e B                     40
# Branch                                                 40
# Brain Waves - Binaural Beats                           40
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                       40
# HealtheLife                                            40
# Binaural Beats Meditation                              40
# BiggerCity: Chat for gay bears, chubs & chasers        40
# Barclays US for Android                                40
# Golf Channel                                           40
# Droid Zap by Motorola                                  40
# Goldstar: Live Event Tickets                           40
# Dungeon Hunter Champions: Epic Online Action RPG       40
# Goal Live Scores                                       40
# Bancomer móvil                                         40
# Banco do Brasil                                        40
# Easy Recipes                                           40
# Baritastic - Bariatric Tracker                         40
# Eat24 Food Delivery & Takeout                          40
# Epocrates Plus                                         40
# GasBuddy: Find Cheap Gas                               40
# Essential Resources                                    40
# Garmin Connect™                                        40
# BLK - Swipe. Match. Chat.                              40
# BIG Launcher                                           40
# Fabulous: Motivate Me! Meditate, Relax, Sleep          40
# Down Dog: Great Yoga Anywhere                          40
# Banco Itaú                                             40
# Baseball Boy!                                          40
# Golf GPS by SwingxSwing                                40
# Betterment                                             40
# Golfshot Plus: Golf GPS                                40
# BeyondPod Podcast Manager                              40
# Google Fit - Fitness Tracking                          40
# Beautiful Widgets Free                                 40
# Delta Dental                                           40
# DoorDash - Food Delivery                               40
# Bathroom Decorating Ideas                              40
# BigOven Recipes, Meal Planner, Grocery List & More     40
# GRE Tutor                                              39
# Family Album Mitene: Private Photo & Video Sharing     39
# Enterprise Rent-A-Car                                  39
# Cheap hotel deals and discounts — Hotellook            39
# Fast News                                              39
# Gems or jewels ?                                       39
# Cheap Flights & Hotels momondo                         39
# HTC Social Plugin - Facebook                           39
# Despegar.com Hoteles y Vuelos                          39
# Farming Simulator 18                                   39
# HTC Speak                                              39
# Etta Homes                                             39
# Caviar - Food Delivery                                 39
# Entel                                                  39
# Healthy Recipes Free                                   39
# Garden Photo Frames - Garden Photo Editor              39
# Garden Fruit Legend                                    39
# EyeCloud                                               39
# FBReader: Favorite Book Reader                         39
# FERZU - Furries Social Network                         39
# Cheapflights – Flight Search                           39
# Chrome Dev                                             39
# Choices: Stories You Play                              39
# Ecobank Mobile Banking                                 39
# H TV                                                   39
# Golf GPS Rangefinder: Golf Pad                         39
# Couch to 5K by RunDouble                               39
# DroidAdmin for Android - Advice                        39
# Cooking Channel                                        39
# Drugs.com Medication Guide                             39
# Gold Butterfly Keyboard Theme                          39
# GroupMe                                                39
# Door Lock Screen                                       39
# GolfLogix GPS + Putt Breaks                            39
# ColorSnap® Visualizer                                  39
# HTC Lock Screen                                        39
# Dominos Game ✔️                                        39
# GoPro (formerly Capture)                               39
# GoBank                                                 39
# Easy Installer - Apps On SD                            39
# Citizens Bank Mobile Banking                           39
# Citibanamex Movil                                      39
# Groovebook Photo Books & Gifts                         39
# Easy Voice Recorder                                    39
# Cisco Webex Meetings                                   39
# Ebook Reader                                           39
# Couchsurfing Travel App                                39
# Diabetes:M                                             39
# DStv Now                                               39
# Bloglovin'                                             39
# 850 Sports News Digest                                 39
# Bike Computer - GPS Cycling Tracker                    39
# AndroZip™ FREE File Manager                            39
# Blur Image Background Editor (Blur Photo Editor)       39
# Binaural Beats Therapy                                 39
# BioLife Plasma Services                                39
# 2RedBeans                                              39
# AlReader -any text book reader                         39
# BBWCupid - BBW Dating App                              39
# Amtrak                                                 39
# Airway Ex - Intubate. Anesthetize. Train.              39
# Banjo                                                  39
# Angry Birds Rio                                        39
# 11st                                                   39
# Babbel – Learn Spanish                                 39
# Blood Pressure                                         39
# Blood Donor                                            39
# CVS Caremark                                           39
# CreditWise from Capital One                            38
# Cricbuzz - Live Cricket Scores & News                  38
# Boys Photo Editor - Six Pack & Men's Suit              38
# Credit Sesame                                          38
# Curriculum vitae App CV Builder Free Resume Maker      38
# Cool Reader                                            38
# Free live weather on screen                            38
# Contacts+                                              38
# Contacts                                               38
# ConnectLine                                            38
# Coloring & Learn                                       38
# Colorfit - Drawing & Coloring                          38
# GolfNow: Tee Time Deals at Golf Courses, Golf GPS      38
# English-Myanmar Dictionary                             38
# Akinator                                               38
# Educational Games 4 Kids                               38
# BeyondMenu Food Delivery                               38
# BeWild Free Dating & Chat App                          38
# Domofond Недвижимость. Купить, снять квартиру.         38
# HD Video Player                                        38
# Goibibo - Flight Hotel Bus Car IRCTC Booking App       38
# FollowMyHealth®                                        38
# Bangla Newspaper – Prothom Alo                         38
# Dunkin' Donuts                                         38
# HTC Weather                                            38
# Blogger                                                38
# Golden Launcher                                        38
# ForecaWeather                                          38
# A&E - Watch Full Episodes of TV Shows                  38
# DSLR Camera Hd Ultra Professional                      38
# Color Touch Effects                                    38
# EasyBib: Citation Generator                            38
# Ebates: Cash Back, Coupons, Rewards & Savings          38
# Eurosport                                              38
# Dosecast - Medication Reminder                         38
# 2Date Dating App, Love and matching                    38
# BELONG Beating Cancer Together                         38
# GS SHOP                                                38
# Chrome Beta                                            38
# EzCalculator                                           38
# Google Handwriting Input                               38
# FINAL FANTASY BRAVE EXVIUS                             38
# Canva: Poster, banner, card maker & graphic design     38
# 1LINE – One Line with One Touch                        38
# CALCU™ Stylish Calculator Free                         38
# Candy Day                                              38
# CWT To Go                                              38
# Google Earth                                           38
# Google                                                 38
# Chapters: Interactive Stories                          38
# HTC Service － DLNA                                     37
# ChatVideo Meet new people                              37
# Aviary Stickers: Free Pack                             37
# Curso de Ingles Gratis                                 37
# Baby Panda Musical Genius                              37
# AutoScout24 Switzerland – Find your new car            37
# CheapTickets – Hotels, Flights & Travel Deals          37
# EatStreet Food Delivery App                            37
# DuraSpeed                                              37
# Ancestry                                               37
# BetterMe: Weight Loss Workouts                         37
# EyeEm - Camera & Photo Filter                          37
# Birds Sounds Ringtones & Wallpapers                    37
# Die TK-App – alles im Griff                            27
# Four In A Line Free                                    27
# ANA                                                    27
# Dino War: Rise of Beasts                               27
# Home Security Camera WardenCam - reuse old phones      26
# BukuBayi - Perkembangan Bayi                           26
# Flip the Gun - Simulator Game                          26
# Cache Cleaner-DU Speed Booster (booster & cleaner)     26
# GO SMS Pro - Messenger, Free Themes, Emoji             26
# Home Workout for Men - Bodybuilding                    26
# Home Workout - No Equipment                            26
# Flights                                                26
# Checkout 51: Grocery coupons                           26
# Banorte Movil                                          26
# Eve Period Tracker - Love, Sex & Relationships App     26
# AT&T Visual Voicemail                                  25
# DELISH KITCHEN - 無料レシピ動画で料理を楽しく・簡単に！                   25
# Home Decor Showpiece Art making: Medium Difficulty     25
# Business Calendar 2                                    25
# Flashlight & LED Torch                                 25
# All Events in City                                     25
# Happy Fruits Bomb - Cube Blast                         25
# Cycling - Bike Tracker                                 25
# BluTV                                                  25
# HBO GO: Stream with TV Package                         25
# Apartment, Home Rental Search: Realtor.com Rentals     25
# Bubble Shooter Space                                   24
# BBC Media Player                                       24
# ASUS Calling Screen                                    24
# Anime Manga Coloring Book                              24
# AirBrush: Easy Photo Editor                            24
# CDL Practice Test 2018 Edition                         24
# Delivery Club–Доставка еды:пицца,суши,бургер,салат     24
# Experian - Free Credit Report                          23
# Couple - Relationship App                              23
# File Explorer                                          23
# Acorn TV: World-class TV from Britain and Beyond       23
# BZWBK24 mobile                                         23
# BankMobile Vibe App                                    23
# ASUS SuperNote                                         23
# Azpen eReader                                          23
# DigiCal Calendar Agenda                                23
# Happy Street                                           22
# Air Traffic                                            22
# British Airways                                        22
# Harkins Theatres                                       22
# GO Weather - Widget, Theme, Wallpaper, Efficient       22
# All-In-One Toolbox: Cleaner, Booster, App Manager      22
# Airport + Flight Tracker Radar                         22
# File Manager -- Take Command of Your Files Easily      22
# HTC File Manager                                       21
# AirAsia                                                21
# Homes.com 🏠 For Sale, Rent                             21
# Housing-Real Estate & Property                         21
# App vault                                              21
# Animal Planet GO                                       21
# BaBe+ - Berita Indonesia                               20
# Amazon for Tablets                                     20
# Fate/Grand Order (English)                             20
# Hot Wheels: Race Off                                   20
# AT&T Smart Wi-Fi                                       20
# 4 in a Row                                             20
# Hole19: Golf GPS App, Rangefinder & Scorecard          19
# Allrecipes Dinner Spinner                              19
# AD - Nieuws, Sport, Regio & Entertainment              19
# Barbie Life™                                           19
# AppLock - Fingerprint                                  19
# HD Camera Ultra                                        18
# Ascape VR: 360° Virtual Travel                         18
# CM Launcher 3D - Theme, Wallpapers, Efficient          18
# Banque Populaire                                       18
# Google Duo - High Quality Video Calls                  18
# Face Filter, Selfie Editor - Sweet Camera              17
# Farming Simulator 14                                   17
# Happy Birthday Songs Offline                           17
# HD Camera Pro for Android                              17
# HD Camera - Quick Snap Photo & Video                   17
# B612 - Beauty & Filter Camera                          16
# Brightest LED Flashlight                               16
# ASUS Sound Recorder                                    16
# Fancy Widgets                                          16
# Brit + Co                                              16
# Advanced Task Killer                                   15
# BaBe - Baca Berita                                     15
# Free Hypnosis                                          15
# Funny Pics                                             15
# Haystack TV: Local & World News - Free                 15
# Dragon Hills                                           15
# 591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價房貸查詢     15
# 7 Weeks - Habit & Goal Tracker                         14
# CIA - Caller ID & Call Blocker                         14
# El tiempo de AEMET                                     14
# Fuzzy Seasons: Animal Forest                           14
# Even - organize your money, get paid early             14
# Extreme Coupon Finder                                  14
# BaBe Lite - Baca Berita Hemat Kuota                    13
# Dinosaur Simulator: Dino World                         13
# Flipboard: News For Our Time                           13
# Genius Scan - PDF Scanner                              13
# AppLock                                                13
# FUN Keyboard – Emoji Keyboard, Sticker,Theme & GIF     12
# Daily Yoga - Yoga Fitness Plans                        12
# File Browser by Astro (File Manager)                   12
# HD Camera - Best Cam with filters & panorama           12
# 7 Minute Workout                                       11
# Headspace: Meditation & Mindfulness                    11
# File Manager                                           11
# FidMe Loyalty Cards & Deals at Grocery Supermarket     11
# Blur Image Background                                  11
# Color Flashlight                                       11
# Bubble Shooter 2                                       11
# FanDuel: Daily Fantasy Sports                          11
# FREEDOME VPN Unlimited anonymous Wifi Security         11
# Bubble Shooter Genies                                  10
# Choice Hotels                                          10
# Best Wallpapers Backgrounds(100,000+ 4K HD)            10
# Baby Tiger Care - My Cute Virtual Pet Friend            9
# 591房屋交易-香港                                              9
# 4K Wallpapers and Ultra HD Backgrounds                  9
# Hitwe - meet people and chat                            9
# 7 Day Food Journal Challenge                            9
# Cameringo Lite. Filters Camera                          9
# Game of Thrones: Conquest™                              9
# English with Lingualeo                                  8
# Google Voice                                            8
# Common Core                                             8
# Home workouts - fat burning, abs, legs, arms,chest      8
# Dictionary - Merriam-Webster                            8
# 7 Cups: Anxiety & Stress Chat                           8
# Dating for 50 plus Mature Singles – FINALLY             7
# 365Scores - Live Scores                                 7
# Find Dining Restaurant Finder                           7
# ASUS Cover for ZenFone 2                                6
# AMC Theatres                                            6
# Burner - Free Phone Number                              6
# Calls & Text by Mo+                                     6
# Dating App, Flirt & Chat : W-Match                      6
# Fitbit                                                  6
# Debonairs Pizza                                         6
# Free Panda Radio Music                                  6
# Daum Mail - 다음 메일                                       5
# All Email Providers                                     5
# Brightest Flashlight Free ®                             5
# Acorns - Invest Spare Change                            5
# Dailyhunt (Newshunt) - Latest News, Viral Videos        4
# Canvas Student                                          4
# Calculator - free calculator, multi calculator app      4
# CM Flashlight (Compass, SOS)                            4
# A Word A Day                                            4
# Happify                                                 4
# GPS Speedometer and Odometer                            4
# BeautyPlus - Easy Photo Editor & Selfie Camera          4
# FlipaClip - Cartoon animation                           4
# Google Street View                                      4
# Dog Sim Online: Raise a Family                          4
# Beauty Makeup Snappy Collage Photo Editor - Lidow       4
# Davis's Drug Guide                                      3
# HelloTalk — Chat, Speak & Learn Foreign Languages       3
# Calls Blacklist - Call Blocker                          3
# Call Blocker                                            3
# Allegiant                                               3
# Anger of stick 5 : zombie                               3
# Call of Duty:Black Ops Zombies                          3
# Buscapé - Ofertas e descontos                           3
# Davis's Drug Guide for Nurses                           3
# Baby Panda’s Juice Shop                                 3
# Dream League Soccer 2018                                3
# Call Control - Call Blocker                             3
# Dairy Queen                                             3
# DEER HUNTER 2018                                        3
# HTC Calendar                                            3
# Best Car Wallpapers                                     3
# Daniel Tiger for Parents                                3
# Calendar Widget Month + Agenda                          2
# CM Browser - Ad Blocker , Fast Download , Privacy       2
# Extreme Car Driving Simulator                           2
# Google Primer                                           2
# Calculator Plus Free                                    2
# Calculator with Percent (Free)                          2
# Google Translate                                        2
# 3D Live Neon Weed Launcher                              2
# Google+                                                 2
# ASUS Quick Memo                                         2
# Dashlane Free Password Manager                          2
# Amazon Prime Video                                      2
# Draw Your Game                                          2
# Disney Heroes: Battle Mode                              2
# Free Live Talk-Video Call                               1
# Calendar+ Schedule Planner App                          1
# DashClock Widget                                        1
# All-in-One Mahjong 3 FREE                               1
# Caller ID +                                             1
# CallApp: Caller ID, Blocker & Phone Call Recorder       1
# Calculator - unit converter                             1
# Fruit Block - Puzzle Legend                             1
# Caf - Mon Compte                                        1
# GPS Map Free                                            1
# Best Ovulation Tracker Fertility Calendar App Glow      1
# HomeWork                                                1
# Apartment Decorating Ideas                              1
# CBS News                                                1
# Google Slides                                           1
# Discover Mobile                                         1
# Google Trips - Travel Planner                           1
# Daily Workouts - Exercise Fitness Routine Trainer       1
# Bed Time Fan - White Noise Sleep Sounds                 1
# Drawing for Kids Learning Games for Toddlers age 3      1
# Draw a Stickman: EPIC 2                                 1
# HD Camera                                               1
# Draw In                                                 1
# Draw A Stickman                                         1
# Best Fiends - Free Puzzle Game                          1
# Name: App, dtype: int64

# %% [markdown]
# #### Now the tough part comes. Let's plan how we will achieve our goal:
#
# 1. We will count the number of reviews that contain *Positive* in the `Sentiment` column.
#
# 1. We will create a new dataframe to contain the `App` name, the number of positive reviews, and the total number of reviews of each app.
#
# 1. We will then loop the new dataframe to calculate the postivie review portion of each app.

# %% [markdown]
# #### Step 1: Count the number of positive reviews.
#
# In the following cell, write a function that takes a column and returns the number of times *Positive* appears in the column.
#
# *Hint: One option is to use the `np.where()` function ([documentation](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.where.html)).*

# %%
# Your code below

def positive_function(x):
    count_positive = (x == 'Positive').sum()
    return count_positive

# %% [markdown]
# #### Step 2: Create a new dataframe to contain the `App` name, the number of positive reviews, and the total number of reviews of each app
#
# We will group `review_missing_removed` by the `App` column, then aggregate the grouped dataframe on the number of positive reviews and the total review counts of each app. The result will be assigned to a new variable `google_agg`. Here is the ([documentation on how to achieve it](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.groupby.DataFrameGroupBy.agg.html)). Take a moment or two to read the documentation and google examples because it is pretty complex.
#
# When you obtain `google_agg`, check its values to make sure it has an `App` column as its index as well as a `Positive` column and a `Total` column. Your output should look like:
#
# ![Positive Reviews Agg](../images/positive-review-agg.png)
#
# *Hint: Use `positive_function` you created earlier as part of the param passed to the `agg()` function in order to aggregate the number of positive reviews.*
#
# #### Bonus:
#
# As of Pandas v0.23.4, you may opt to supply an array or an object to `agg()`. If you use the array param, you'll need to rename the columns so that their names are `Positive` and `Total`. Using the object param will allow you to create the aggregated columns with the desirable names without renaming them. However, you will probably encounter a warning indicating supplying an object to `agg()` will become outdated. It's up to you which way you will use. Try both ways out. Any way is fine as long as it works.

# %%
# Your code here:
google_agg = review_missing_removed.groupby(by="App").agg(
        Positive=('Sentiment', positive_function),
        Total=('Translated_Review', 'count')                 
    )

# %% [markdown]
# Print the first 5 rows of `google_agg` to check it.

# %%
# Your code here
google_agg.head(5)
# Out:
#                                   Positive  Total
# App
# 10 Best Foods for You                  162    194
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室        31     40
# 11st                                    23     39
# 1800 Contacts - Lens Store              64     80
# 1LINE – One Line with One Touch         27     38

# %% [markdown]
# #### Add a derived column to `google_agg` that is the ratio of the `Positive` and the `Total` columns. Call this column `Positive Ratio`.
#
# Make sure to account for the case where the denominator is zero using the `np.where()` function.

# %%
# Your code here:

google_agg['Positive Ratio'] = np.where(google_agg['Total'] == 0, 0, google_agg['Positive'] / google_agg['Total'])

# %%
google_agg
# Out:
#                                                     Positive  Total  \
# App
# 10 Best Foods for You                                    162    194
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                          31     40
# 11st                                                      23     39
# 1800 Contacts - Lens Store                                64     80
# 1LINE – One Line with One Touch                           27     38
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif          25     32
# 21-Day Meditation Experience                              68     80
# 2Date Dating App, Love and matching                       26     38
# 2GIS: directory & navigator                               23     40
# 2RedBeans                                                 31     39
# 2ndLine - Second Phone Number                             17     40
# 30 Day Fitness Challenge - Workout at Home                27     31
# 365Scores - Live Scores                                    5      7
# 3D Live Neon Weed Launcher                                 2      2
# 4 in a Row                                                17     20
# 4K Wallpapers and Ultra HD Backgrounds                     7      9
# 591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價房貸查詢         5     15
# 591房屋交易-香港                                                 5      9
# 7 Cups: Anxiety & Stress Chat                              7      8
# 7 Day Food Journal Challenge                               9      9
# 7 Minute Workout                                          10     11
# 7 Weeks - Habit & Goal Tracker                            10     14
# 8 Ball Pool                                              104    219
# 850 Sports News Digest                                    38     39
# 8fit Workouts & Meal Planner                             137    171
# 95Live -SG#1 Live Streaming App                           34     78
# A Call From Santa Claus!                                  20     34
# A Word A Day                                               3      4
# A&E - Watch Full Episodes of TV Shows                     30     38
# A+ Gallery - Photos & Videos                              24     41
# A+ Mobile                                                 57     84
# ABC Kids - Tracing & Phonics                              30     37
# ABC News - US & World News                                18     70
# ABC Preschool Free                                        19     36
# ABCmouse.com                                              25     36
# AC - Tips & News for Android™                             18     35
# ACE Elite                                                 22     33
# AD - Nieuws, Sport, Regio & Entertainment                 13     19
# AMC Theatres                                               5      6
# ANA                                                        6     27
# AOL - News, Mail & Video                                  17     33
# AP Mobile - Breaking News                                 31     36
# APE Weather ( Live Forecast)                              25     33
# APUS Launcher - Theme, Wallpaper, Hide Apps               25     31
# ARY NEWS                                                  18     33
# ARY NEWS URDU                                             19     34
# ASOS                                                      52     66
# ASUS Calling Screen                                        9     24
# ASUS Cover for ZenFone 2                                   3      6
# ASUS Quick Memo                                            1      2
# ASUS Sound Recorder                                       13     16
# ASUS SuperNote                                            14     23
# AT&T Navigator: Maps, Traffic                             16     29
# AT&T Smart Wi-Fi                                          11     20
# AT&T Visual Voicemail                                     11     25
# AVG Cleaner – Speed, Battery & Memory Booster             29     35
# Abs Training-Burn belly fat                               25     36
# Account Manager                                           11     33
# Accounting App - Zoho Books                               56     71
# AccuWeather: Daily Forecast & Live Weather Reports        23     32
# Acorn TV: World-class TV from Britain and Beyond          14     23
# Acorns - Invest Spare Change                               2      5
# AdWords Express                                           20     50
# Ada - Your Health Guide                                   54     63
# Add Text To Photo                                         18     34
# Adobe Acrobat Reader                                     119    162
# Adobe Photoshop Express:Photo Editor Collage Maker        32     42
# Advanced Task Killer                                      11     15
# Agar.io                                                   60    136
# Age Calculator                                            19     32
# Agoda – Hotel Booking Deals                               30     35
# Air Traffic                                               16     22
# AirAsia                                                    8     21
# AirBrush: Easy Photo Editor                               17     24
# Airbnb                                                    36     62
# Airport + Flight Tracker Radar                            13     22
# Airway Ex - Intubate. Anesthetize. Train.                 25     39
# Akinator                                                  19     38
# AlReader -any text book reader                            24     39
# Alarm Clock                                               22     36
# Alarm Clock Free                                          19     34
# Alfred Home Security Camera                               21     30
# AliExpress - Smarter Shopping, Better Living              29     45
# All Email Providers                                        3      5
# All Events in City                                        23     25
# All Football - Latest News & Videos                       27     32
# All Football GO- Live Score, Games                        30     36
# All Language Translator Free                              24     30
# All Maths Formulas                                        26     33
# All Mental disorders                                      43     65
# All Social Networks                                       12     34
# All Video Downloader 2018                                 23     34
# All-In-One Toolbox: Cleaner, Booster, App Manager         15     22
# All-in-One Mahjong 3 FREE                                  1      1
# Allegiant                                                  2      3
# Allrecipes Dinner Spinner                                 16     19
# Alto's Adventure                                         103    175
# Amazon Drive                                              18     36
# Amazon FreeTime – Kids’ Videos, Books, & TV shows         28     35
# Amazon Kindle                                             65    117
# Amazon Prime Video                                         2      2
# Amazon Shopping                                           22     45
# Amazon for Tablets                                        10     20
# American Airlines                                         20     43
# Amex Mobile                                               20     36
# Amino: Communities and Chats                              23     35
# Amtrak                                                    11     39
# Anatomy Learning - 3D Atlas                               28     36
# Ancestry                                                  28     37
# AndroZip™ FREE File Manager                               21     39
# Android Auto - Maps, Media, Messaging & Voice             30     31
# Android Messages                                          23     43
# Anger of stick 5 : zombie                                  2      3
# Angry Birds 2                                             16     29
# Angry Birds Classic                                      124    273
# Angry Birds Rio                                           15     39
# Animal Planet GO                                          14     21
# Animated Photo Editor                                     21     35
# Anime Avatar Creator: Make Your Own Avatar                18     28
# Anime Manga Coloring Book                                 19     24
# Anthem Anywhere                                           19     65
# Anthem BC Anywhere                                         8     31
# Any.do: To-do list, Calendar, Reminders & Planner         74     98
# Apartment Decorating Ideas                                 1      1
# Apartment List: Housing, Apt, and Property Rentals        42     47
# Apartment, Home Rental Search: Realtor.com Rentals        12     25
# Apartments & Rentals - Zillow                             28     44
# Apartments.com Rental Search                              32     69
# Apex Launcher                                             37     60
# Apk Installer                                             18     27
# App vault                                                  8     21
# AppLock                                                    6     13
# AppLock - Fingerprint                                     16     19
# BeWild Free Dating & Chat App                             31     38
# Beautiful Design Birthday Cake                            21     36
# Beautiful Widgets Free                                    20     40
# Beautiful Widgets Pro                                     30     37
# Beauty Camera - Selfie Camera                             23     36
# Beauty Makeup Snappy Collage Photo Editor - Lidow          2      4
# BeautyPlus - Easy Photo Editor & Selfie Camera             2      4
# Bed Time Fan - White Noise Sleep Sounds                    1      1
# Best Car Wallpapers                                        1      3
# Best Fiends - Free Puzzle Game                             1      1
# Best Ovulation Tracker Fertility Calendar App Glow         1      1
# Best Wallpapers Backgrounds(100,000+ 4K HD)                6     10
# Best Wallpapers QHD                                       30     35
# BestCam Selfie-selfie, beauty camera, photo editor        28     99
# BetterMe: Weight Loss Workouts                            27     37
# Betterment                                                25     40
# BeyondMenu Food Delivery                                  35     38
# BeyondPod Podcast Manager                                 32     40
# Bible                                                     81     97
# Big Days - Events Countdown                               24     36
# BigOven Recipes, Meal Planner, Grocery List & More        34     40
# BiggerCity: Chat for gay bears, chubs & chasers           27     40
# Bike Computer - GPS Cycling Tracker                       27     39
# Binaural Beats Meditation                                 29     40
# Binaural Beats Therapy                                    28     39
# BioLife Plasma Services                                   24     39
# Birdays – Birthday reminder                               33     37
# Birds Sounds Ringtones & Wallpapers                       27     37
# Black People Meet Singles Date                            19     28
# Block Puzzle                                              83    154
# Block Puzzle Classic Legend !                             46     72
# Blogaway for Android (Blogger)                            19     36
# Blogger                                                   31     38
# Bloglovin'                                                19     39
# Blood Donor                                               26     39
# Blood Pressure                                            31     39
# Blood Pressure Log - MyDiary                              35     40
# Blood Pressure(BP) Diary                                  14     40
# Bloomberg Professional                                    15     40
# Bloomberg: Market & Financial News                        15     40
# Blossom Blast Saga                                        17     36
# BluTV                                                     16     25
# Blur Image Background                                      8     11
# Blur Image Background Editor (Blur Photo Editor)          26     39
# Booking.com Travel Deals                                  54    120
# Bowmasters                                               169    312
# Box                                                       81    117
# Boxed Wholesale                                           30     40
# Boys Photo Editor - Six Pack & Men's Suit                 23     38
# Brain Waves - Binaural Beats                              32     40
# Branch                                                    28     40
# Brasileirão Pro 2018 - Série A e B                        34     40
# Breaking News, Local news, Attacks and Alerts Free        14     27
# Brightest Flashlight Free ®                                5      5
# Brightest LED Flashlight                                  13     16
# Brilliant                                                 21     28
# Brit + Co                                                 10     16
# British Airways                                           13     22
# Browser 4G                                                23     34
# Bualuang mBanking                                         11     34
# Bubble Shooter                                           100    145
# Bubble Shooter 2                                           8     11
# Bubble Shooter Genies                                      6     10
# Bubble Shooter Space                                      14     24
# Bubble Witch 3 Saga                                       19     31
# Buienradar - weer                                         20     35
# Build a Bridge!                                           50     86
# Bukalapak - Jual Beli Online                              14     31
# BukuBayi - Perkembangan Bayi                              21     26
# Burner - Free Phone Number                                 5      6
# Buscapé - Ofertas e descontos                              2      3
# Business Calendar 2                                       18     25
# Butterfly Live Wallpaper                                  20     28
# Buzz Launcher-Smart&Free Theme                            25     36
# BuzzFeed: News, Tasty, Quizzes                            47     71
# BÁO MỚI - Đọc Báo, Tin Tức 24h                            18     34
# C Programming                                             32     35
# C++ Programming                                           24     36
# C++ Tutorials                                             32     36
# CAIXA                                                     11     34
# CALCU™ Stylish Calculator Free                            27     38
# CATS: Crash Arena Turbo Stars                             35     57
# CBS News                                                   0      1
# CBS Sports App - Scores, News, Stats & Watch Live        123    192
# CBS Sports Fantasy                                        34     54
# CDL Practice Test 2018 Edition                            21     24
# CIA - Caller ID & Call Blocker                             8     14
# CM Browser - Ad Blocker , Fast Download , Privacy          1      2
# CM Flashlight (Compass, SOS)                               4      4
# CM Launcher 3D - Theme, Wallpapers, Efficient             12     18
# CM Locker - Security Lockscreen                           56     86
# CMB Free Dating App                                       55     71
# CNBC: Breaking Business News & Live Market Data           25     37
# CNN Breaking US & World News                              65    112
# COOKING MAMA Let's Cook!                                  26     36
# CVS Caremark                                              23     39
# CW Seed                                                   25     36
# CWT To Go                                                 28     38
# Cache Cleaner-DU Speed Booster (booster & cleaner)        16     26
# Caf - Mon Compte                                           1      1
# Calculator - free calculator, multi calculator app         1      4
# Calculator - unit converter                                1      1
# Calculator Plus Free                                       2      2
# Calculator with Percent (Free)                             1      2
# Calendar Widget Month + Agenda                             1      2
# Calendar+ Schedule Planner App                             1      1
# Call Blocker                                               1      3
# Call Control - Call Blocker                                0      3
# Call of Duty:Black Ops Zombies                             0      3
# CallApp: Caller ID, Blocker & Phone Call Recorder          1      1
# Caller ID +                                                1      1
# Calls & Text by Mo+                                        5      6
# Calls Blacklist - Call Blocker                             2      3
# Calm - Meditate, Sleep, Relax                             56     65
# Calorie Counter & Diet Tracker                           109    135
# Calorie Counter - EasyFit free                            33     37
# Calorie Counter - Macros                                 174    200
# Calorie Counter - MyFitnessPal                           169    254
# Calorie Counter - MyNetDiary                             120    139
# Cameringo Lite. Filters Camera                             8      9
# Candy Bomb                                                62     72
# Candy Camera - selfie, beauty camera, photo editor        73    114
# Candy Crush Jelly Saga                                    21     73
# Candy Crush Saga                                         102    240
# Candy Crush Soda Saga                                     62    166
# Candy Day                                                 26     38
# Candy Pop Story                                           22     40
# Candy Smash                                               28     40
# Candy selfie - photo editor, live filter camera           21     33
# Canva: Poster, banner, card maker & graphic design        30     38
# Canvas Student                                             2      4
# Cat Sim Online: Play with Cats                            45     61
# Caviar - Food Delivery                                    25     39
# Chakra Cleansing                                          35     40
# Championat                                                25     40
# Chapters: Interactive Stories                             30     38
# Chase Mobile                                              23     40
# Chat Rooms, Avatars, Date - Galaxy                        46     74
# ChatVideo Meet new people                                 20     37
# Cheap Flights & Hotels momondo                            24     39
# Cheap hotel deals and discounts — Hotellook               24     39
# CheapTickets – Hotels, Flights & Travel Deals             27     37
# Cheapflights – Flight Search                              28     39
# CheckPoints 🏆 Rewards App                                 28     40
# Checkers ✔️                                               18     36
# Checkout 51: Grocery coupons                              21     26
# Choice Hotels                                              7     10
# Choices: Stories You Play                                 21     39
# Christian Dating For Free App                             50     76
# Chrome Beta                                               22     38
# Chrome Dev                                                25     39
# Fantasy Football Manager (FPL)                            24     34
# Farm Fruit Pop: Party Time                                19     31
# Farm Heroes Saga                                          46    110
# Farming Simulator 14                                      11     17
# Farming Simulator 18                                      24     39
# Fashion in Vogue                                          46    113
# Fast News                                                 28     39
# Fast Scanner : Free PDF Scan                              58     74
# Fast Secure VPN                                           37     71
# FastMeet: Chat, Dating, Love                              54     75
# Fat Burning Workout - Home Weight lose                    24     36
# Fate/Grand Order (English)                                11     20
# FidMe Loyalty Cards & Deals at Grocery Supermarket         6     11
# File Browser by Astro (File Manager)                       7     12
# File Explorer                                             14     23
# File Manager                                               3     11
# File Manager -- Take Command of Your Files Easily         10     22
# Files Go by Google: Free up space on your phone           25     34
# FilterGrid - Cam&Photo Editor                             22     35
# Filters for B Live                                        13     30
# Filters for Selfie                                        31     63
# Final Fantasy XV: A New Empire                            13     32
# Financial Times                                           20     30
# Find Dining Restaurant Finder                              6      7
# Find a Way: Addictive Puzzle                              19     30
# Find&Save - Local Shopping                                20     31
# FindShip                                                  18     34
# Firefox Browser fast & private                            45     62
# Firefox Focus: The privacy browser                        54     64
# Fishdom                                                   81    123
# Fitbit                                                     5      6
# Flashlight                                                28     35
# Flashlight & LED Torch                                    10     25
# Flashlight - Torch LED Light                              21     30
# Flashlight HD LED                                         27     29
# Flickr                                                    35     64
# Flight & Hotel Booking App - ixigo                        21     33
# Flightradar24 Flight Tracker                              26     32
# Flights                                                   15     26
# Flip the Gun - Simulator Game                             14     26
# FlipaClip - Cartoon animation                              4      4
# Flipboard: News For Our Time                              10     13
# Flipkart Online Shopping App                              19     28
# Flipp - Weekly Shopping                                   29     31
# Flippy Campus - Buy & sell on campus at a discount        26     34
# FlirtChat - ♥Free Dating/Flirting App♥                    51     70
# Floor Plan Creator                                        26     37
# Flow Free                                                101    154
# Flowers Live Wallpaper                                    21     33
# Fly Delta                                                 47     71
# FollowMyHealth®                                           32     38
# Font Studio- Photo Texts Image                            23     34
# Food Calorie Calculator                                   16     41
# Food Network                                              31     71
# Fooducate Healthy Weight Loss & Calorie Counter           30     37
# Foot Mercato : transferts, résultats, news, live          26     36
# Football Live Scores                                      28     34
# ForecaWeather                                             29     38
# Fortune City - A Finance App                              41     48
# Four In A Line                                            49     61
# Four In A Line Free                                       18     27
# Foursquare City Guide                                     15     28
# Foursquare Swarm: Check In                                 9     29
# Fox Business                                              22     34
# Fox News – Breaking News, Live Video & News Alerts        55    105
# Fraction Calculator Plus Free                             24     31
# Free & Premium VPN - FinchVPN                             21     31
# Free Dating & Flirt Chat - Choice of Love                 10     35
# Free Dating App & Flirt Chat - Cheers                     18     32
# Free Dating App & Flirt Chat - Match with Singles         21     33
# Free Dating App - Meet Local Singles - Flirt Chat         27     67
# Free Dating App - YoCutie - Flirt, Chat & Meet            36     59
# Free Dating Hook Up Messenger                             43     64
# Free Foreclosure Real Estate Search by USHUD.com          14     37
# Free Hypnosis                                             14     15
# Free Live Talk-Video Call                                  0      1
# Free Panda Radio Music                                     3      6
# Free Sports TV                                            16     27
# GO Notifier                                               0.617647
# GO SMS Pro - Messenger, Free Themes, Emoji                0.500000
# GO Weather - Widget, Theme, Wallpaper, Efficient          0.636364
# GPS Map Free                                              1.000000
# GPS Speedometer and Odometer                              1.000000
# GPS Speedometer, Distance Meter                           0.750000
# GPS Status & Toolbox                                      0.742857
# GPS Traffic Speedcam Route Planner by ViaMichelin         0.694444
# GRE Flashcards                                            0.777778
# GRE Prep & Practice by Magoosh                            0.777778
# GRE Tutor                                                 0.820513
# GS SHOP                                                   0.552632
# GUNSHIP BATTLE: Helicopter 3D                             0.529412
# Galactic Core Free Wallpaper                              0.833333
# Galaxy Attack: Alien Shooter                              0.619403
# Game of Thrones: Conquest™                                0.666667
# Gametime - Tickets to Sports, Concerts, Theater           0.891892
# Garden Coloring Book                                      0.711111
# Garden Fruit Legend                                       0.743590
# Garden Photo Frames - Garden Photo Editor                 0.641026
# Gardenscapes                                              0.526316
# Garena Free Fire                                          0.612613
# Garmin Connect™                                           0.675000
# GasBuddy: Find Cheap Gas                                  0.725000
# Gay Sugar Daddy Dating & Hookup – Sudy Gay                0.641026
# Gboard - the Google Keyboard                              0.526316
# Gems or jewels ?                                          0.564103
# Genius Scan - PDF Scanner                                 0.846154
# Gmail                                                     0.515625
# GoBank                                                    0.487179
# GoPro (formerly Capture)                                  0.384615
# Goal Live Scores                                          0.675000
# Goibibo - Flight Hotel Bus Car IRCTC Booking App          0.710526
# Goku Wallpaper Art                                        0.714286
# Gold Butterfly Keyboard Theme                             0.769231
# Golden Dictionary (EN-AR)                                 0.675676
# Golden Launcher                                           0.815789
# Goldstar: Live Event Tickets                              0.950000
# Golf Channel                                              0.300000
# Golf GPS Rangefinder: Golf Pad                            0.794872
# Golf GPS by SwingxSwing                                   0.800000
# GolfLogix GPS + Putt Breaks                               0.384615
# GolfNow: Tee Time Deals at Golf Courses, Golf GPS         0.763158
# Golfshot Plus: Golf GPS                                   0.750000
# Golfshot: Golf GPS + Tee Times                            0.750000
# GoodRx Drug Prices and Coupons                            0.648649
# Google                                                    0.736842
# Google Ads                                                0.569444
# Google Duo - High Quality Video Calls                     0.833333
# Google Earth                                              0.605263
# Google Fit - Fitness Tracking                             0.550000
# Google Handwriting Input                                  0.552632
# Google Keep                                               0.675000
# Google My Business                                        0.589744
# Google News                                               0.666667
# Google PDF Viewer                                         0.550000
# Google Pay                                                0.692308
# Google Photos                                             0.748691
# Google Primer                                             1.000000
# Google Slides                                             1.000000
# Google Street View                                        0.000000
# Google Translate                                          1.000000
# Google Trips - Travel Planner                             1.000000
# Google Voice                                              0.500000
# Google+                                                   1.000000
# Granny                                                    0.655172
# Graphing Calculator                                       0.658228
# Grim Soul: Dark Fantasy Survival                          0.611111
# Groovebook Photo Books & Gifts                            0.769231
# GroupMe                                                   0.717949
# Groupon - Shop Deals, Discounts & Coupons                 0.791667
# Grubhub: Food Delivery                                    0.526316
# Guns of Glory                                             0.350000
# Gyft - Mobile Gift Card Wallet                            0.450000
# Homes.com 🏠 For Sale, Rent                                0.523810
# Homescapes                                                0.519231
# Homesnap Real Estate & Rentals                            0.714286
# Homestyler Interior Design & Decorating Ideas             0.558824
# Homework Planner                                          0.891892
# Honkai Impact 3rd                                         0.710526
# Hopper - Watch & Book Flights                             0.710526
# Horoscopes – Daily Zodiac Horoscope and Astrology         0.600000
# Horses Live Wallpaper                                     0.666667
# Hostelworld: Hostels & Cheap Hotels Travel App            0.646154
# Hot Wheels: Race Off                                      0.700000
# HotelTonight: Book amazing deals at great hotels          0.732283
# Hotels Combined - Cheap deals                             0.416667
# Hotels.com: Book Hotel Rooms & Find Vacation Deals        0.573529
# Hotspot Shield Free VPN Proxy & Wi-Fi Security            0.500000
# Hotstar                                                   0.437500
# Hotwire Hotel & Car Rental App                            0.484848
# Housing-Real Estate & Property                            0.380952

# %% [markdown]
# #### Now drop the `Positive` and `Total` columns. Do this with `inplace=True`.

# %%
# Your code here:
google_agg.drop(['Positive', 'Total'], axis=1, inplace=True)

# %% [markdown]
# Print the first 5 rows of `google_agg`. Your output should look like:
#
# ![Positive Reviews Agg](../images/positive-review-ratio.png)

# %%
# Your code here:
google_agg.head(5)
# Out:
#                                   Positive Ratio
# App
# 10 Best Foods for You                   0.835052
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室        0.775000
# 11st                                    0.589744
# 1800 Contacts - Lens Store              0.800000
# 1LINE – One Line with One Touch         0.710526

# %% [markdown]
# # Challenge 3 - Join the Dataframes
#
# In this part of the lab, we will join the two dataframes and obtain a dataframe that contains features we can use in our ML algorithm.
#
# In the next cell, join the `google_missing_removed` dataframe with the `google_agg` dataframe on the `App` column. Assign this dataframe to the variable `google`.

# %%
# Your code here:
google = pd.merge(google_missing_removed, google_agg, on='App')

# %% [markdown]
# #### Let's look at the final result using the `head()` function. Your final product should look like:
#
# ![Final Product](../images/google-final-head.png)

# %%
# Your code here:
google.head()
# Out:
#                                          App        Category  Rating  \
# 0                        Coloring book moana  ART_AND_DESIGN     3.9
# 1                        Coloring book moana          FAMILY     3.9
# 2                       Garden Coloring Book  ART_AND_DESIGN     4.4
# 3              FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3
# 4  Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1
#
#     Reviews    Installs  Type Content Rating                     Genres  \
# 0     967.0    500,000+  Free       Everyone  Art & Design;Pretend Play
# 1     974.0    500,000+  Free       Everyone  Art & Design;Pretend Play
# 2   13791.0  1,000,000+  Free       Everyone               Art & Design
# 3  194216.0  5,000,000+  Free       Everyone               Art & Design
# 4     654.0    100,000+  Free       Everyone               Art & Design
#
#   Last Updated Current Ver   Android Ver  Reviews_numeric  Reviews_isnull  \
# 0   2018-01-15       2.0.0  4.0.3 and up            967.0           False
# 1   2018-01-15       2.0.0  4.0.3 and up            974.0           False
# 2   2017-09-20       2.9.2    3.0 and up          13791.0           False
# 3   2018-08-03       2.2.5  4.0.3 and up         194216.0           False
# 4   2018-03-20         1.1  4.0.3 and up            654.0           False
#
#    Price Numerical  Positive Ratio
# 0              0.0        0.590909
# 1              0.0        0.590909
# 2              0.0        0.711111
# 3              0.0        1.000000
# 4              0.0        0.605263
